# %%
import pandas as pd
from Handler import *
import os

# %%
path_data = "/Volumes/elmichelangelo_external_ssd_1/Data/gaNdalF_paper_catalogs"
path_data_master_cat = "/Volumes/elmichelangelo_external_ssd_1/Data"
filename_clf_balrog = "balrog_clf_Test_sample_2024-09-28_13-18.pkl"
filename_clf_gandalf = "gandalf_clf_Test_sample_2024-09-28_13-18.pkl"
filename_master_cat = "Y3_mastercat_02_05_21.h5"
path_save_plots = "/Users/P.Gebhardt/Development/PhD/output/gaNdalF_paper"

# %%
def apply_deep_cuts(path_data, filename_master_cat, data_frame):
    """"""
    data_frame = flag_cuts(data_frame=data_frame)
    data_frame = mask_cut(
        data_frame=data_frame,
        master=f"{path_data}/{filename_master_cat}"
    )
    return data_frame

# %%
df_balrog_clf = pd.read_pickle(f"{path_data}/{filename_clf_balrog}")
df_gandalf_clf = pd.read_pickle(f"{path_data}/{filename_clf_gandalf}")

# %%
df_balrog_clf_deep_cut = apply_deep_cuts(path_data_master_cat, filename_master_cat, df_balrog_clf)
df_gandalf_clf_deep_cut = apply_deep_cuts(path_data_master_cat, filename_master_cat, df_gandalf_clf)
# Out:
# Apply flag cuts
# Length of catalog after applying flag cuts: 16708354
# define mask
# pass:  15761612
# fail:  946742
# Apply flag cuts
# Length of catalog after applying flag cuts: 16708354
# define mask
# pass:  15761612
# fail:  946742

# %%
print(f"Length of Balrog detected objects: {len(df_balrog_clf[df_balrog_clf['detected'] == 1])}")
print(f"Length of Balrog not detected objects: {len(df_balrog_clf[df_balrog_clf['detected'] == 0])}")
print(f"Length of gaNdalF detected objects: {len(df_gandalf_clf[df_gandalf_clf['detected'] == 1])}")
print(f"Length of gaNdalF not detected objects: {len(df_gandalf_clf[df_gandalf_clf['detected'] == 0])}")

print(
    f"Length of Balrog detected deep cut objects: {len(df_balrog_clf_deep_cut[df_balrog_clf_deep_cut['detected'] == 1])}")
print(
    f"Length of Balrog not detected deep cut objects: {len(df_balrog_clf_deep_cut[df_balrog_clf_deep_cut['detected'] == 0])}")
print(
    f"Length of gaNdalF detected deep cut objects: {len(df_gandalf_clf_deep_cut[df_gandalf_clf_deep_cut['detected'] == 1])}")
print(
    f"Length of gaNdalF not detected deep cut objects: {len(df_gandalf_clf_deep_cut[df_gandalf_clf_deep_cut['detected'] == 0])}")
# Out:
# Length of Balrog detected objects: 8604186
# Length of Balrog not detected objects: 11604177
# Length of gaNdalF detected objects: 8606503
# Length of gaNdalF not detected objects: 11601860
# Length of Balrog detected deep cut objects: 7086393
# Length of Balrog not detected deep cut objects: 8675219
# Length of gaNdalF detected deep cut objects: 6938677
# Length of gaNdalF not detected deep cut objects: 8822935

# %%
plot_number_density_fluctuation(
    df_balrog=df_balrog_clf,
    df_gandalf=df_gandalf_clf,
    columns=[
        "BDF_MAG_DERED_CALIB_R",
        "BDF_MAG_DERED_CALIB_I",
        "BDF_MAG_DERED_CALIB_Z",
        "BDF_T",
        "BDF_G",
        "FWHM_WMEAN_R",
        "FWHM_WMEAN_I",
        "FWHM_WMEAN_Z",
        "AIRMASS_WMEAN_R",
        "AIRMASS_WMEAN_I",
        "AIRMASS_WMEAN_Z",
        "MAGLIM_R",
        "MAGLIM_I",
        "MAGLIM_Z",
        "EBV_SFD98"
    ],
    labels=[
        "BDF Mag R",
        "BDF Mag I",
        "BDF Mag Z",
        "BDF T",
        "BDF G",
        "FWHM R",
        "FWHM I",
        "FWHM Z",
        "AIRMASS R",
        "AIRMASS I",
        "AIRMASS Z",
        "MAGLIM R",
        "MAGLIM I",
        "MAGLIM Z",
        "EBV SFD98"
    ],
    ranges=[
        [18, 26],
        [18, 26],
        [18, 26],
        [-1, 1.5],
        [-0.1, 0.8],
        [0.8, 1.2],
        [0.7, 1.1],
        [0.7, 1.0],
        [1, 1.4],
        [1, 1.4],
        [1, 1.4],
        [23.5, 24.5],
        [23, 23.75],
        [22, 23],
        [0, 0.05]
    ],
    show_plot=False,
    save_plot=True,
    save_name=f"{path_save_plots}/number_density_fluctuation.png",
    title=f"Number Density Fluctuation Analysis of gaNdalF vs. Balrog Detections"
)

# %%
plot_number_density_fluctuation(
    df_balrog=df_balrog_clf_deep_cut,
    df_gandalf=df_gandalf_clf_deep_cut,
    columns=[
        "BDF_MAG_DERED_CALIB_R",
        "BDF_MAG_DERED_CALIB_I",
        "BDF_MAG_DERED_CALIB_Z",
        "BDF_T",
        "BDF_G",
        "FWHM_WMEAN_R",
        "FWHM_WMEAN_I",
        "FWHM_WMEAN_Z",
        "AIRMASS_WMEAN_R",
        "AIRMASS_WMEAN_I",
        "AIRMASS_WMEAN_Z",
        "MAGLIM_R",
        "MAGLIM_I",
        "MAGLIM_Z",
        "EBV_SFD98"
    ],
    labels=[
        "BDF Mag R",
        "BDF Mag I",
        "BDF Mag Z",
        "BDF T",
        "BDF G",
        "FWHM R",
        "FWHM I",
        "FWHM Z",
        "AIRMASS R",
        "AIRMASS I",
        "AIRMASS Z",
        "MAGLIM R",
        "MAGLIM I",
        "MAGLIM Z",
        "EBV SFD98"
    ],
    ranges=[
        [18, 26],
        [18, 26],
        [18, 26],
        [-1, 1.5],
        [-0.1, 0.8],
        [0.8, 1.2],
        [0.7, 1.1],
        [0.7, 1.0],
        [1, 1.4],
        [1, 1.4],
        [1, 1.4],
        [23.5, 24.5],
        [23, 23.75],
        [22, 23],
        [0, 0.05]
    ],
    show_plot=False,
    save_plot=True,
    save_name=f"{path_save_plots}/number_density_fluctuation_deep_cut.png",
    title=f"Number Density Fluctuation Analysis of GANDALF vs. Balrog Detections with Deep Cut Applied"
)

# %%
plot_multivariate_classifier(
    df_balrog=df_balrog_clf,
    df_gandalf=df_gandalf_clf,
    grid_size=[4, 4],
    x_range=(17.8, 26.3),
    columns={
        "BDF_MAG_DERED_CALIB_R": {
            "label": "BDF Mag R",
            "range": [18.5, 28],
            "position": [0, 0]
        },
        "BDF_MAG_DERED_CALIB_Z": {
            "label": "BDF Mag Z",
            "range": [18, 26],
            "position": [0, 1]
        },
        "BDF_T": {
            "label": "BDF T",
            "range": [-0.25, 1.8],
            "position": [0, 2]
        },
        "BDF_G": {
            "label": "BDF G",
            "range": [-0.1, 0.9],
            "position": [1, 0]
        },
        "FWHM_WMEAN_R": {
            "label": "FWHM R",
            "range": [0.7, 1.3],
            "position": [1, 1]
        },
        "FWHM_WMEAN_I": {
            "label": "FWHM I",
            "range": [0.7, 1.1],
            "position": [1, 2]
        },
        "FWHM_WMEAN_Z": {
            "label": "FWHM Z",
            "range": [0.6, 1.16],
            "position": [2, 0]
        },
        "AIRMASS_WMEAN_R": {
            "label": "AIRMASS R",
            "range": [0.95, 1.45],
            "position": [2, 1]
        },
        "AIRMASS_WMEAN_I": {
            "label": "AIRMASS I",
            "range": [1, 1.45],
            "position": [2, 2]
        },
        "AIRMASS_WMEAN_Z": {
            "label": "AIRMASS Z",
            "range": [1, 1.4],
            "position": [2, 3]
        },
        "MAGLIM_R": {
            "label": "MAGLIM R",
            "range": [23, 24.8],
            "position": [3, 0]
        },
        "MAGLIM_I": {
            "label": "MAGLIM I",
            "range": [22.4, 24.0],
            "position": [3, 1]
        },
        "MAGLIM_Z": {
            "label": "MAGLIM Z",
            "range": [21.8, 23.2],
            "position": [3, 2]
        },
        "EBV_SFD98": {
            "label": "EBV SFD98",
            "range": [-0.01, 0.10],
            "position": [3, 3]
        }
    },
    show_plot=False,
    save_plot=True,
    save_name=f"{path_save_plots}/classifier_multiv.png",
    title=f"Multivariate Comparison of Detection Distributions in gaNdalF and Balrog"
)
# Out:
# Elapsed time: 0d 0h 1m 10s
# Plotting column: BDF_MAG_DERED_CALIB_R (1/14)
# Elapsed time: 0d 0h 1m 11s
# Elapsed time: 0d 0h 1m 12s
# Elapsed time: 0d 0h 1m 13s
# Elapsed time: 0d 0h 1m 14s
# Plotting column: BDF_MAG_DERED_CALIB_Z (2/14)
# Elapsed time: 0d 0h 1m 15s
# Elapsed time: 0d 0h 1m 15s
# Elapsed time: 0d 0h 1m 16s
# Elapsed time: 0d 0h 1m 17s
# Plotting column: BDF_T (3/14)
# Elapsed time: 0d 0h 1m 18s
# Elapsed time: 0d 0h 1m 19s
# Elapsed time: 0d 0h 1m 20s
# Elapsed time: 0d 0h 1m 21s
# Plotting column: BDF_G (4/14)
# Elapsed time: 0d 0h 1m 21s
# Elapsed time: 0d 0h 1m 22s
# Elapsed time: 0d 0h 1m 23s
# Elapsed time: 0d 0h 1m 24s
# Plotting column: FWHM_WMEAN_R (5/14)
# Elapsed time: 0d 0h 1m 25s
# Elapsed time: 0d 0h 1m 25s
# Elapsed time: 0d 0h 1m 26s
# Elapsed time: 0d 0h 1m 27s
# Plotting column: FWHM_WMEAN_I (6/14)
# Elapsed time: 0d 0h 1m 28s
# Elapsed time: 0d 0h 1m 28s
# Elapsed time: 0d 0h 1m 29s
# Elapsed time: 0d 0h 1m 30s
# Plotting column: FWHM_WMEAN_Z (7/14)
# Elapsed time: 0d 0h 1m 31s
# Elapsed time: 0d 0h 1m 31s
# Elapsed time: 0d 0h 1m 32s
# Elapsed time: 0d 0h 1m 33s
# Plotting column: AIRMASS_WMEAN_R (8/14)
# Elapsed time: 0d 0h 1m 34s
# Elapsed time: 0d 0h 1m 34s
# Elapsed time: 0d 0h 1m 36s
# Elapsed time: 0d 0h 1m 36s
# Plotting column: AIRMASS_WMEAN_I (9/14)
# Elapsed time: 0d 0h 1m 37s
# Elapsed time: 0d 0h 1m 38s
# Elapsed time: 0d 0h 1m 39s
# Elapsed time: 0d 0h 1m 39s
# Plotting column: AIRMASS_WMEAN_Z (10/14)
# Elapsed time: 0d 0h 1m 40s
# Elapsed time: 0d 0h 1m 41s
# Elapsed time: 0d 0h 1m 42s
# Elapsed time: 0d 0h 1m 43s
# Plotting column: MAGLIM_R (11/14)
# Elapsed time: 0d 0h 1m 43s
# Elapsed time: 0d 0h 1m 44s
# Elapsed time: 0d 0h 1m 45s
# Elapsed time: 0d 0h 1m 46s
# Plotting column: MAGLIM_I (12/14)
# Elapsed time: 0d 0h 1m 46s
# Elapsed time: 0d 0h 1m 47s
# Elapsed time: 0d 0h 1m 48s
# Elapsed time: 0d 0h 1m 49s
# Plotting column: MAGLIM_Z (13/14)
# Elapsed time: 0d 0h 1m 49s
# Elapsed time: 0d 0h 1m 50s
# Elapsed time: 0d 0h 1m 51s
# Elapsed time: 0d 0h 1m 52s
# Plotting column: EBV_SFD98 (14/14)
# Elapsed time: 0d 0h 1m 52s
# Elapsed time: 0d 0h 1m 53s
# Elapsed time: 0d 0h 1m 54s

# %%
plot_multivariate_classifier(
    df_balrog=df_balrog_clf_deep_cut,
    df_gandalf=df_gandalf_clf_deep_cut,
    grid_size=[4, 4],
    x_range=(17.8, 26.3),
    columns={
        "BDF_MAG_DERED_CALIB_R": {
            "label": "BDF Mag R",
            "range": [18.5, 28],
            "position": [0, 0]
        },
        "BDF_MAG_DERED_CALIB_Z": {
            "label": "BDF Mag Z",
            "range": [18, 26],
            "position": [0, 1]
        },
        "BDF_T": {
            "label": "BDF T",
            "range": [-0.25, 1.8],
            "position": [0, 2]
        },
        "BDF_G": {
            "label": "BDF G",
            "range": [-0.1, 0.9],
            "position": [1, 0]
        },
        "FWHM_WMEAN_R": {
            "label": "FWHM R",
            "range": [0.7, 1.3],
            "position": [1, 1]
        },
        "FWHM_WMEAN_I": {
            "label": "FWHM I",
            "range": [0.7, 1.1],
            "position": [1, 2]
        },
        "FWHM_WMEAN_Z": {
            "label": "FWHM Z",
            "range": [0.6, 1.16],
            "position": [2, 0]
        },
        "AIRMASS_WMEAN_R": {
            "label": "AIRMASS R",
            "range": [0.95, 1.45],
            "position": [2, 1]
        },
        "AIRMASS_WMEAN_I": {
            "label": "AIRMASS I",
            "range": [1, 1.45],
            "position": [2, 2]
        },
        "AIRMASS_WMEAN_Z": {
            "label": "AIRMASS Z",
            "range": [1, 1.4],
            "position": [2, 3]
        },
        "MAGLIM_R": {
            "label": "MAGLIM R",
            "range": [23, 24.8],
            "position": [3, 0]
        },
        "MAGLIM_I": {
            "label": "MAGLIM I",
            "range": [22.4, 24.0],
            "position": [3, 1]
        },
        "MAGLIM_Z": {
            "label": "MAGLIM Z",
            "range": [21.8, 23.2],
            "position": [3, 2]
        },
        "EBV_SFD98": {
            "label": "EBV SFD98",
            "range": [-0.01, 0.10],
            "position": [3, 3]
        }
    },
    show_plot=False,
    save_plot=True,
    save_name=f"{path_save_plots}/classifier_multiv_deep_cut.png",
    title=f"Multivariate Comparison of Detection Distributions in gaNdalF and Balrog with Deep Cut Applied"
)
# Out:
# Elapsed time: 0d 0h 0m 48s
# Plotting column: BDF_MAG_DERED_CALIB_R (1/14)
# Elapsed time: 0d 0h 0m 48s
# Elapsed time: 0d 0h 0m 49s
# Elapsed time: 0d 0h 0m 49s
# Elapsed time: 0d 0h 0m 50s
# Plotting column: BDF_MAG_DERED_CALIB_Z (2/14)
# Elapsed time: 0d 0h 0m 50s
# Elapsed time: 0d 0h 0m 51s
# Elapsed time: 0d 0h 0m 51s
# Elapsed time: 0d 0h 0m 52s
# Plotting column: BDF_T (3/14)
# Elapsed time: 0d 0h 0m 53s
# Elapsed time: 0d 0h 0m 53s
# Elapsed time: 0d 0h 0m 54s
# Elapsed time: 0d 0h 0m 54s
# Plotting column: BDF_G (4/14)
# Elapsed time: 0d 0h 0m 55s
# Elapsed time: 0d 0h 0m 55s
# Elapsed time: 0d 0h 0m 56s
# Elapsed time: 0d 0h 0m 56s
# Plotting column: FWHM_WMEAN_R (5/14)
# Elapsed time: 0d 0h 0m 57s
# Elapsed time: 0d 0h 0m 57s
# Elapsed time: 0d 0h 0m 58s
# Elapsed time: 0d 0h 0m 58s
# Plotting column: FWHM_WMEAN_I (6/14)
# Elapsed time: 0d 0h 0m 59s
# Elapsed time: 0d 0h 1m 0s
# Elapsed time: 0d 0h 1m 0s
# Elapsed time: 0d 0h 1m 1s
# Plotting column: FWHM_WMEAN_Z (7/14)
# Elapsed time: 0d 0h 1m 1s
# Elapsed time: 0d 0h 1m 2s
# Elapsed time: 0d 0h 1m 3s
# Elapsed time: 0d 0h 1m 3s
# Plotting column: AIRMASS_WMEAN_R (8/14)
# Elapsed time: 0d 0h 1m 4s
# Elapsed time: 0d 0h 1m 4s
# Elapsed time: 0d 0h 1m 5s
# Elapsed time: 0d 0h 1m 5s
# Plotting column: AIRMASS_WMEAN_I (9/14)
# Elapsed time: 0d 0h 1m 6s
# Elapsed time: 0d 0h 1m 6s
# Elapsed time: 0d 0h 1m 7s
# Elapsed time: 0d 0h 1m 8s
# Plotting column: AIRMASS_WMEAN_Z (10/14)
# Elapsed time: 0d 0h 1m 8s
# Elapsed time: 0d 0h 1m 9s
# Elapsed time: 0d 0h 1m 9s
# Elapsed time: 0d 0h 1m 10s
# Plotting column: MAGLIM_R (11/14)
# Elapsed time: 0d 0h 1m 10s
# Elapsed time: 0d 0h 1m 11s
# Elapsed time: 0d 0h 1m 11s
# Elapsed time: 0d 0h 1m 12s
# Plotting column: MAGLIM_I (12/14)
# Elapsed time: 0d 0h 1m 12s
# Elapsed time: 0d 0h 1m 13s
# Elapsed time: 0d 0h 1m 13s
# Elapsed time: 0d 0h 1m 14s
# Plotting column: MAGLIM_Z (13/14)
# Elapsed time: 0d 0h 1m 14s
# Elapsed time: 0d 0h 1m 15s
# Elapsed time: 0d 0h 1m 15s
# Elapsed time: 0d 0h 1m 16s
# Plotting column: EBV_SFD98 (14/14)
# Elapsed time: 0d 0h 1m 17s
# Elapsed time: 0d 0h 1m 17s
# Elapsed time: 0d 0h 1m 18s
