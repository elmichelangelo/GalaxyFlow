# %%
import pandas as pd
from Handler import *
import os

# %%
# path_data = "/project/ls-gruen/users/patrick.gebhardt/data/gaNdalF_paper_catalogs"
path_data_master_cat = "/Volumes/elmichelangelo_external_ssd_1/Data/gaNdalF"
path_data = "/Volumes/elmichelangelo_external_ssd_1/Data/gaNdalF_paper_catalogs"
filename_clf_balrog = "balrog_clf_Test_sample_2024-09-28_13-18.pkl"
# filename_clf_balrog = "2024-09-28_14-13_balrog_clf_Test_sample.pkl"
filename_clf_gandalf = "gandalf_clf_Test_sample_2024-09-28_13-18.pkl"
# filename_clf_gandalf = "2024-09-28_14-13_gandalf_clf_Test_sample.pkl"
filename_emr_balrog = "2024-09-28_14-13_balrog_emr_Test_sample.pkl"
filename_emr_gandalf = "2024-09-28_14-13_gandalf_emr_Test_sample.pkl"
filename_master_cat = "Y3_mastercat_02_05_21.h5"
path_save_plots = ""

# %%
def apply_deep_cuts(path_data, filename_master_cat, data_frame):
    """"""
    data_frame = flag_cuts(data_frame=data_frame)
    #data_frame = mask_cut_healpy(
    #    data_frame=data_frame,
    #    master=f"{path_data}/{filename_master_cat}"
    #)
    data_frame = mask_cut(
        data_frame=data_frame,
        master=f"{path_data}/{filename_master_cat}"
    )
    return data_frame

# %%
df_balrog_clf = pd.read_pickle(f"{path_data}/{filename_clf_balrog}")
df_gandalf_clf = pd.read_pickle(f"{path_data}/{filename_clf_gandalf}")

# %%
plot_number_density_fluctuation(
                df_balrog=df_balrog_clf,
                df_gandalf=df_gandalf_clf,
                columns=[
                    "BDF_MAG_DERED_CALIB_R",
                    "BDF_MAG_DERED_CALIB_I",
                    "BDF_MAG_DERED_CALIB_Z",
                    "BDF_T",
                    "BDF_G",
                    "FWHM_WMEAN_R",
                    "FWHM_WMEAN_I",
                    "FWHM_WMEAN_Z",
                    "AIRMASS_WMEAN_R",
                    "AIRMASS_WMEAN_I",
                    "AIRMASS_WMEAN_Z",
                    "MAGLIM_R",
                    "MAGLIM_I",
                    "MAGLIM_Z",
                    "EBV_SFD98"
                ],
                labels=[
                    "BDF Mag R",
                    "BDF Mag I",
                    "BDF Mag Z",
                    "BDF T",
                    "BDF G",
                    "FWHM R",
                    "FWHM I",
                    "FWHM Z",
                    "AIRMASS R",
                    "AIRMASS I",
                    "AIRMASS Z",
                    "MAGLIM R",
                    "MAGLIM I",
                    "MAGLIM Z",
                    "EBV SFD98"
                ],
                ranges=[
                    [18, 26],
                    [18, 26],
                    [18, 26],
                    [-1, 1.5],
                    [-0.1, 0.8],
                    [0.8, 1.2],
                    [0.7, 1.1],
                    [0.7, 1.0],
                    [1, 1.4],
                    [1, 1.4],
                    [1, 1.4],
                    [23.5, 24.5],
                    [23, 23.75],
                    [22, 23],
                    [0, 0.05]
                ],
                show_plot=True,
                save_plot=False,
                save_name=f"{path_save_plots}/number_density_fluctuation.png",
                title=f"Comparison Between Gandalf and Balrog"
            )

# %%
df_balrog_deep_clf_cut = apply_deep_cuts(path_data_master_cat, filename_master_cat, df_balrog_clf)
df_gandalf_deep_clf_cut = apply_deep_cuts(path_data_master_cat, filename_master_cat, df_gandalf_clf)
# Out:
# Apply flag cuts
# Length of catalog after applying flag cuts: 16708354
# define mask
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_balrog_deep_clf_cut = apply_deep_cuts(path_data_master_cat, filename_master_cat, df_balrog_clf)
#       2 df_gandalf_deep_clf_cut = apply_deep_cuts(path_data_master_cat, filename_master_cat, df_gandalf_clf)
#
# Cell In[18], line 8, in apply_deep_cuts(path_data, filename_master_cat, data_frame)
#       3 data_frame = flag_cuts(data_frame=data_frame)
#       4 #data_frame = mask_cut_healpy(
#       5 #    data_frame=data_frame,
#       6 #    master=f"{path_data}/{filename_master_cat}"
#       7 #)
# ----> 8 data_frame = mask_cut(
#       9     data_frame=data_frame,
#      10     master=f"{path_data}/{filename_master_cat}"
#      11 )
#      12 return data_frame
#
# File ~/Development/PhD/GalaxyFlow/Handler/cut_functions.py:94, in mask_cut(data_frame, master, prob)
#      92 import h5py
#      93 print("define mask")
# ---> 94 f = h5py.File(master)
#      95 hpix = data_frame['HPIX_4096'].to_numpy()
#      96 mask_cut = np.in1d(hpix, f['index/mask/hpix'][:], assume_unique=False)
#
# File ~/Development/PhD/GalaxyFlow/venv/lib/python3.10/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~/Development/PhD/GalaxyFlow/venv/lib/python3.10/site-packages/h5py/_hl/files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/Volumes/elmichelangelo_external_ssd_1/Data/gaNdalF/Y3_mastercat_02_05_21.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
plot_number_density_fluctuation(
                df_balrog=df_balrog_deep_clf_cut,
                df_gandalf=df_gandalf_deep_clf_cut,
                columns=[
                    "BDF_MAG_DERED_CALIB_R",
                    "BDF_MAG_DERED_CALIB_I",
                    "BDF_MAG_DERED_CALIB_Z",
                    "BDF_T",
                    "BDF_G",
                    "FWHM_WMEAN_R",
                    "FWHM_WMEAN_I",
                    "FWHM_WMEAN_Z",
                    "AIRMASS_WMEAN_R",
                    "AIRMASS_WMEAN_I",
                    "AIRMASS_WMEAN_Z",
                    "MAGLIM_R",
                    "MAGLIM_I",
                    "MAGLIM_Z",
                    "EBV_SFD98"
                ],
                labels=[
                    "BDF Mag R",
                    "BDF Mag I",
                    "BDF Mag Z",
                    "BDF T",
                    "BDF G",
                    "FWHM R",
                    "FWHM I",
                    "FWHM Z",
                    "AIRMASS R",
                    "AIRMASS I",
                    "AIRMASS Z",
                    "MAGLIM R",
                    "MAGLIM I",
                    "MAGLIM Z",
                    "EBV SFD98"
                ],
                ranges=[
                    [18, 26],
                    [18, 26],
                    [18, 26],
                    [-1, 1.5],
                    [-0.1, 0.8],
                    [0.8, 1.2],
                    [0.7, 1.1],
                    [0.7, 1.0],
                    [1, 1.4],
                    [1, 1.4],
                    [1, 1.4],
                    [23.5, 24.5],
                    [23, 23.75],
                    [22, 23],
                    [0, 0.05]
                ],
                show_plot=True,
                save_plot=False,
                save_name=f"{path_save_plots}/number_density_fluctuation.png",
                title=f"Comparison Between Gandalf and Balrog"
            )

# %%
plot_multivariate_classifier(
                df_balrog=df_balrog_clf,
                df_gandalf=df_gandalf_clf,
                columns=[
                    "BDF_MAG_DERED_CALIB_R",
                    "BDF_MAG_DERED_CALIB_Z",
                    "BDF_T",
                    "BDF_G",
                    "FWHM_WMEAN_R",
                    "FWHM_WMEAN_I",
                    "FWHM_WMEAN_Z",
                    "AIRMASS_WMEAN_R",
                    "AIRMASS_WMEAN_I",
                    "AIRMASS_WMEAN_Z",
                    "MAGLIM_R",
                    "MAGLIM_I",
                    "MAGLIM_Z",
                    "EBV_SFD98"
                ],
                labels=[
                    "BDF Mag R",
                    "BDF Mag Z",
                    "BDF T",
                    "BDF G",
                    "FWHM R",
                    "FWHM I",
                    "FWHM Z",
                    "AIRMASS R",
                    "AIRMASS I",
                    "AIRMASS Z",
                    "MAGLIM R",
                    "MAGLIM I",
                    "MAGLIM Z",
                    "EBV SFD98"
                ],
                ranges=[
                    [18, 26],
                    [18, 26],
                    [-1, 1.5],
                    [-0.1, 0.8],
                    [0.8, 1.2],
                    [0.7, 1.1],
                    [0.7, 1.0],
                    [1, 1.4],
                    [1, 1.4],
                    [1, 1.4],
                    [23.5, 24.5],
                    [23, 23.75],
                    [22, 23],
                    [0, 0.05]
                ],
                show_plot=True,
                save_plot=False,
                save_name=f"/classifier_multiv.png",
                title=f"Comparison Between Gandalf and Balrog"
            )
