# %%
import pandas as pd
from Handler import *

# %%
path_data = "/project/ls-gruen/users/patrick.gebhardt/data/gaNdalF_paper_catalogs"
# path_data = "/Volumes/elmichelangelo_external_ssd_1/Data/gaNdalF_paper_catalogs"
filename_clf_balrog = "balrog_clf_Test_sample_2024-09-28_13-18.pkl"
filename_clf_gandalf = "gandalf_clf_Test_sample_2024-09-28_13-18.pkl"
path_save_plots = ""

# %%
df_balrog = pd.read_pickle(f"{path_data}/{filename_clf_balrog}")
df_gandalf = pd.read_pickle(f"{path_data}/{filename_clf_balrog}")

# %%
plot_number_density_fluctuation(
                df_balrog=df_balrog,
                df_gandalf=df_gandalf,
                columns=[
                    "BDF_MAG_DERED_CALIB_R",
                    "BDF_MAG_DERED_CALIB_I",
                    "BDF_MAG_DERED_CALIB_Z",
                    "BDF_T",
                    "BDF_G",
                    "FWHM_WMEAN_R",
                    "FWHM_WMEAN_I",
                    "FWHM_WMEAN_Z",
                    "AIRMASS_WMEAN_R",
                    "AIRMASS_WMEAN_I",
                    "AIRMASS_WMEAN_Z",
                    "MAGLIM_R",
                    "MAGLIM_I",
                    "MAGLIM_Z",
                    "EBV_SFD98"
                ],
                labels=[
                    "BDF Mag R",
                    "BDF Mag I",
                    "BDF Mag Z",
                    "BDF T",
                    "BDF G",
                    "FWHM R",
                    "FWHM I",
                    "FWHM Z",
                    "AIRMASS R",
                    "AIRMASS I",
                    "AIRMASS Z",
                    "MAGLIM R",
                    "MAGLIM I",
                    "MAGLIM Z",
                    "EBV SFD98"
                ],
                ranges=[
                    [18, 26],
                    [18, 26],
                    [18, 26],
                    [-1, 1.5],
                    [-0.1, 0.8],
                    [0.8, 1.2],
                    [0.7, 1.1],
                    [0.7, 1.0],
                    [1, 1.4],
                    [1, 1.4],
                    [1, 1.4],
                    [23.5, 24.5],
                    [23, 23.75],
                    [22, 23],
                    [0, 0.05]
                ],
                show_plot=True,
                save_plot=False,
                save_name=f"{path_save_plots}/number_density_fluctuation.png",
                title=f"Comparison Between Gandalf and Balrog"
            )
